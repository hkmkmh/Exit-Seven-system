# %%
# !pip install ultralytics
# !pip install gdown
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.9/871.9 kB 41.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pokYEcxlDzdngF40Yrmx")
project = rf.workspace("exit-seven").project("exit-seven-project")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.92, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Exit-Seven-Project-5 in yolov8:: 100%|██████████| 19612/19612 [00:03<00:00, 6243.96it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

results = model.train(data="/content/Exit-Seven-Project-4/data.yaml",
                      epochs=50,
                      imgsz=640,
                      patience=50,
                      project='/content/drive/MyDrive/Model',
                      name='yolov8m_training_final_final_final',
                      # resume=True
                      )
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Model/yolov8m_training_final_final_final/weights/last.pt")  # load a pretrained model (recommended for training)

results = model.train(data="/content/Exit-Seven-Project-5/data.yaml",
                      epochs=50,
                      imgsz=640,
                      patience=50,
                      project='/content/drive/MyDrive/Model',
                      name='yolov8m_training_final_upgrade',
                      # resume=True
                      )
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
#final
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/confusion_matrix.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/confusion_matrix.png', height=640)

# %%
#final
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/results.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/results.png', height=640)

# %%
#final
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/F1_curve.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/F1_curve.png', height=640)

# %%
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/PR_curve.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/PR_curve.png', height=640)

# %%
#final
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/P_curve.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/P_curve.png', height=640)

# %%
#final
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_final_final/R_curve.png', height=640)

# %%
#final upgrade
Image(filename='/content/drive/MyDrive/Model/yolov8m_training_final_upgrade2/R_curve.png', height=640)
